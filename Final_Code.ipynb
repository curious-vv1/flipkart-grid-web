# %%
X1, Y1 = 25, 500
X2, Y2 = 2125, 2000

# %%
# Function to apply K-means clustering segmentation and create an inverse mask
def kmeans_segmentation(roi_frame, k=2):
    # Convert the frame to a 2D array of pixels
    pixel_values = roi_frame.reshape((-1, 3))
    pixel_values = np.float32(pixel_values)

    # Define the criteria for the K-means algorithm
    criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 100, 0.2)

    # Apply K-means clustering
    _, labels, centers = cv2.kmeans(pixel_values, k, None, criteria, 10, cv2.KMEANS_RANDOM_CENTERS)
    
    # Convert back to 8-bit values and reshape to the original image dimensions
    centers = np.uint8(centers)
    segmented_roi = centers[labels.flatten()]
    segmented_roi = segmented_roi.reshape(roi_frame.shape)

    # Convert to grayscale (for binary mask creation)
    gray_roi = cv2.cvtColor(segmented_roi, cv2.COLOR_BGR2GRAY)

    # Create an inverse binary mask (thresholding)
    _, mask = cv2.threshold(gray_roi, 128, 255, cv2.THRESH_BINARY_INV)

    # Apply erosion followed by dilation (morphological operations)
    kernel = np.ones((9, 9), np.uint8)  # You can adjust the kernel size if needed
    eroded_mask = cv2.erode(mask, kernel, iterations=2)
    dilated_mask = cv2.dilate(eroded_mask, kernel, iterations=5)

    return dilated_mask

# %%
def area_calculated(frame, width, height, resize_factor, X1, Y1, X2, Y2):
    # Resize the original frame by the specified factor
    resized_frame = cv2.resize(frame, (int(width / resize_factor),
                                        int(height / resize_factor)))

    # Ensure the ROI coordinates fit the resized frame
    roi_X1 = max(0, int(X1 / resize_factor))
    roi_Y1 = max(0, int(Y1 / resize_factor))
    roi_X2 = min(resized_frame.shape[1], int(X2 / resize_factor))
    roi_Y2 = min(resized_frame.shape[0], int(Y2 / resize_factor))

    # Crop the frame to the ROI
    roi_frame = resized_frame[roi_Y1:roi_Y2, roi_X1:roi_X2]

    if roi_frame.size == 0:
        print(f"Error: Empty ROI with coordinates {(roi_X1, roi_Y1, roi_X2, roi_Y2)}")
        return resized_frame  # Skip this frame if ROI is invalid

    # Apply K-means clustering and morphological operations inside the ROI
    mask = kmeans_segmentation(roi_frame, k=2)

    # Convert the mask back to 3 channels to overlay it on the original frame
    mask_3channel = cv2.cvtColor(mask, cv2.COLOR_GRAY2BGR)

    # Place the segmented ROI mask back into the original resized frame
    resized_frame[roi_Y1:roi_Y2, roi_X1:roi_X2] = mask_3channel

    return resized_frame

# %%
def model_predict(frame, model, width, height, resize_factor, X1, Y1, X2, Y2):
    
    # Draw the ROI rectangle on the full frame
    cv2.rectangle(frame, (X1, Y1), (X2, Y2), (0, 0, 0), 20)  # Black rectangle with 20px thickness

    # Crop the frame to the specified ROI for prediction
    roi_frame = frame[Y1:Y2, X1:X2]

    # Perform prediction on the cropped ROI frame (assumed model is defined)
    results = model.predict(source=roi_frame)

    # Get the result (this will return the frame with bounding boxes or segmentation)
    segmented_frame = results[0].plot()

    # Place the segmented frame back into the original frame at the ROI location
    frame[Y1:Y2, X1:X2] = segmented_frame

    # Resize the full frame for display
    resized_frame = cv2.resize(frame, (width // resize_factor, height // resize_factor))

    return resized_frame

# %%
def main(video_path,model, resize_factor, roi_coordinates):
    X1, Y1, X2, Y2 = roi_coordinates
    cap = cv2.VideoCapture(video_path)

 
    if not cap.isOpened():
        print("Error: Could not open video.")
        return  


    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

    # Loop through the video frames
    while cap.isOpened():
        ret, frame = cap.read()

        # Break the loop if no more frames
        if not ret:
            print("Error: Could not read frame.")
            break

        processed_frame = area_calculated(frame, width, height, resize_factor, X1, Y1, X2, Y2)
        predicted_frame = model_predict(frame, model, width, height, resize_factor, X1, Y1, X2, Y2)

        collage = np.hstack((predicted_frame, processed_frame))
    
        cv2.imshow('Collage Frame', collage)
 
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break

    cap.release()
    cv2.destroyAllWindows()

# %%
main(video_path, model, resize_factor, roi_coordinates)
# Out:
# 0: 480x640 1 Rotten Potato, 193.6ms
# Speed: 10.4ms preprocess, 193.6ms inference, 56.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 35.0ms
# Speed: 4.8ms preprocess, 35.0ms inference, 5.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 150.5ms
# Speed: 3.1ms preprocess, 150.5ms inference, 4.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 35.0ms
# Speed: 5.5ms preprocess, 35.0ms inference, 6.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 33.7ms
# Speed: 8.4ms preprocess, 33.7ms inference, 6.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 38.0ms
# Speed: 1.5ms preprocess, 38.0ms inference, 5.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 62.6ms
# Speed: 5.5ms preprocess, 62.6ms inference, 9.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 77.8ms
# Speed: 0.0ms preprocess, 77.8ms inference, 4.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 169.6ms
# Speed: 0.0ms preprocess, 169.6ms inference, 8.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 31.4ms
# Speed: 8.3ms preprocess, 31.4ms inference, 9.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 39.3ms
# Speed: 2.5ms preprocess, 39.3ms inference, 8.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 63.2ms
# Speed: 3.5ms preprocess, 63.2ms inference, 15.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 70.7ms
# Speed: 3.1ms preprocess, 70.7ms inference, 8.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 86.2ms
# Speed: 0.0ms preprocess, 86.2ms inference, 4.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 179.7ms
# Speed: 7.4ms preprocess, 179.7ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 37.6ms
# Speed: 0.0ms preprocess, 37.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 46.8ms
# Speed: 1.5ms preprocess, 46.8ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 138.2ms
# Speed: 5.3ms preprocess, 138.2ms inference, 5.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 45.5ms
# Speed: 4.0ms preprocess, 45.5ms inference, 5.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 49.3ms
# Speed: 0.0ms preprocess, 49.3ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 46.1ms
# Speed: 4.1ms preprocess, 46.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 78.1ms
# Speed: 2.1ms preprocess, 78.1ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 159.2ms
# Speed: 5.4ms preprocess, 159.2ms inference, 10.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 151.6ms
# Speed: 9.0ms preprocess, 151.6ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 36.7ms
# Speed: 4.6ms preprocess, 36.7ms inference, 8.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 40.2ms
# Speed: 0.0ms preprocess, 40.2ms inference, 5.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 154.3ms
# Speed: 0.0ms preprocess, 154.3ms inference, 6.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 154.2ms
# Speed: 5.5ms preprocess, 154.2ms inference, 9.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 48.4ms
# Speed: 10.4ms preprocess, 48.4ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 41.0ms
# Speed: 7.0ms preprocess, 41.0ms inference, 10.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 70.2ms
# Speed: 9.1ms preprocess, 70.2ms inference, 11.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 90.7ms
# Speed: 5.0ms preprocess, 90.7ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 159.4ms
# Speed: 0.8ms preprocess, 159.4ms inference, 7.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 148.4ms
# Speed: 7.6ms preprocess, 148.4ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 33.9ms
# Speed: 9.6ms preprocess, 33.9ms inference, 6.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 39.0ms
# Speed: 4.5ms preprocess, 39.0ms inference, 5.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 61.8ms
# Speed: 5.1ms preprocess, 61.8ms inference, 9.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 166.2ms
# Speed: 3.7ms preprocess, 166.2ms inference, 5.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 156.8ms
# Speed: 3.9ms preprocess, 156.8ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 29.5ms
# Speed: 0.8ms preprocess, 29.5ms inference, 10.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 40.7ms
# Speed: 2.0ms preprocess, 40.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 53.6ms
# Speed: 0.0ms preprocess, 53.6ms inference, 9.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 72.0ms
# Speed: 3.5ms preprocess, 72.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 90.7ms
# Speed: 5.0ms preprocess, 90.7ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 150.2ms
# Speed: 5.2ms preprocess, 150.2ms inference, 9.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 149.4ms
# Speed: 1.5ms preprocess, 149.4ms inference, 5.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 41.5ms
# Speed: 8.3ms preprocess, 41.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 40.6ms
# Speed: 3.0ms preprocess, 40.6ms inference, 5.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 40.6ms
# Speed: 6.0ms preprocess, 40.6ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 153.1ms
# Speed: 0.0ms preprocess, 153.1ms inference, 8.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 150.2ms
# Speed: 4.4ms preprocess, 150.2ms inference, 9.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 34.2ms
# Speed: 8.5ms preprocess, 34.2ms inference, 5.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 35.6ms
# Speed: 1.0ms preprocess, 35.6ms inference, 4.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 79.2ms
# Speed: 0.0ms preprocess, 79.2ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 80.9ms
# Speed: 7.5ms preprocess, 80.9ms inference, 7.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 81.0ms
# Speed: 0.0ms preprocess, 81.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 155.4ms
# Speed: 6.3ms preprocess, 155.4ms inference, 8.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 149.0ms
# Speed: 7.8ms preprocess, 149.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 139.8ms
# Speed: 10.4ms preprocess, 139.8ms inference, 3.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 40.5ms
# Speed: 0.0ms preprocess, 40.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 36.4ms
# Speed: 4.1ms preprocess, 36.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 67.6ms
# Speed: 1.0ms preprocess, 67.6ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 81.9ms
# Speed: 0.0ms preprocess, 81.9ms inference, 8.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 96.6ms
# Speed: 0.0ms preprocess, 96.6ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 160.0ms
# Speed: 0.6ms preprocess, 160.0ms inference, 4.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 149.4ms
# Speed: 4.1ms preprocess, 149.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 45.6ms
# Speed: 0.4ms preprocess, 45.6ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 33.3ms
# Speed: 7.7ms preprocess, 33.3ms inference, 8.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 59.9ms
# Speed: 2.2ms preprocess, 59.9ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 70.6ms
# Speed: 6.5ms preprocess, 70.6ms inference, 4.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Rotten Potatos, 87.0ms
# Speed: 2.3ms preprocess, 87.0ms inference, 2.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 154.2ms
# Speed: 7.5ms preprocess, 154.2ms inference, 8.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 147.5ms
# Speed: 6.6ms preprocess, 147.5ms inference, 8.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 32.3ms
# Speed: 0.0ms preprocess, 32.3ms inference, 8.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 35.6ms
# Speed: 4.5ms preprocess, 35.6ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 40.5ms
# Speed: 0.0ms preprocess, 40.5ms inference, 7.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 149.7ms
# Speed: 7.1ms preprocess, 149.7ms inference, 5.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 152.4ms
# Speed: 0.0ms preprocess, 152.4ms inference, 5.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 31.3ms
# Speed: 8.7ms preprocess, 31.3ms inference, 9.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 42.6ms
# Speed: 5.3ms preprocess, 42.6ms inference, 5.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 32.4ms
# Speed: 3.0ms preprocess, 32.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 63.3ms
# Speed: 2.6ms preprocess, 63.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 71.6ms
# Speed: 9.3ms preprocess, 71.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 81.2ms
# Speed: 8.6ms preprocess, 81.2ms inference, 8.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 147.8ms
# Speed: 8.3ms preprocess, 147.8ms inference, 7.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 49.2ms
# Speed: 6.5ms preprocess, 49.2ms inference, 3.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 48.8ms
# Speed: 5.1ms preprocess, 48.8ms inference, 5.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 53.2ms
# Speed: 1.9ms preprocess, 53.2ms inference, 6.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 160.5ms
# Speed: 7.6ms preprocess, 160.5ms inference, 9.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 32.2ms
# Speed: 0.0ms preprocess, 32.2ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 32.6ms
# Speed: 0.0ms preprocess, 32.6ms inference, 8.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 32.7ms
# Speed: 7.5ms preprocess, 32.7ms inference, 8.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 147.9ms
# Speed: 1.5ms preprocess, 147.9ms inference, 9.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 32.6ms
# Speed: 7.4ms preprocess, 32.6ms inference, 8.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 32.5ms
# Speed: 4.0ms preprocess, 32.5ms inference, 5.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 34.0ms
# Speed: 3.5ms preprocess, 34.0ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 147.1ms
# Speed: 3.2ms preprocess, 147.1ms inference, 5.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 143.9ms
# Speed: 3.4ms preprocess, 143.9ms inference, 6.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 37.7ms
# Speed: 0.0ms preprocess, 37.7ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 31.5ms
# Speed: 2.4ms preprocess, 31.5ms inference, 8.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 40.5ms
# Speed: 3.4ms preprocess, 40.5ms inference, 8.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 60.2ms
# Speed: 0.5ms preprocess, 60.2ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 65.4ms
# Speed: 5.5ms preprocess, 65.4ms inference, 8.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 85.4ms
# Speed: 0.0ms preprocess, 85.4ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 159.5ms
# Speed: 0.0ms preprocess, 159.5ms inference, 10.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 31.2ms
# Speed: 9.0ms preprocess, 31.2ms inference, 9.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 32.7ms
# Speed: 2.1ms preprocess, 32.7ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 35.7ms
# Speed: 3.5ms preprocess, 35.7ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 154.4ms
# Speed: 1.0ms preprocess, 154.4ms inference, 6.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 34.9ms
# Speed: 0.0ms preprocess, 34.9ms inference, 9.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 35.2ms
# Speed: 3.0ms preprocess, 35.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 31.2ms
# Speed: 9.5ms preprocess, 31.2ms inference, 9.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 150.0ms
# Speed: 5.5ms preprocess, 150.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 150.5ms
# Speed: 0.7ms preprocess, 150.5ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 36.7ms
# Speed: 2.5ms preprocess, 36.7ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 39.2ms
# Speed: 0.0ms preprocess, 39.2ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 48.4ms
# Speed: 0.0ms preprocess, 48.4ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 65.3ms
# Speed: 0.0ms preprocess, 65.3ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Rotten Potatos, 70.7ms
# Speed: 6.0ms preprocess, 70.7ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 163.3ms
# Speed: 0.8ms preprocess, 163.3ms inference, 6.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Rotten Potatos, 46.3ms
# Speed: 2.6ms preprocess, 46.3ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 36.3ms
# Speed: 4.0ms preprocess, 36.3ms inference, 4.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 34.4ms
# Speed: 4.6ms preprocess, 34.4ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Rotten Potatos, 58.0ms
# Speed: 3.0ms preprocess, 58.0ms inference, 9.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 70.2ms
# Speed: 4.5ms preprocess, 70.2ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Rotten Potatos, 161.4ms
# Speed: 8.6ms preprocess, 161.4ms inference, 8.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 43.2ms
# Speed: 0.0ms preprocess, 43.2ms inference, 6.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 31.4ms
# Speed: 9.0ms preprocess, 31.4ms inference, 8.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 39.0ms
# Speed: 0.0ms preprocess, 39.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 59.1ms
# Speed: 1.4ms preprocess, 59.1ms inference, 10.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 79.0ms
# Speed: 0.0ms preprocess, 79.0ms inference, 6.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 165.6ms
# Speed: 4.9ms preprocess, 165.6ms inference, 9.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 150.3ms
# Speed: 5.6ms preprocess, 150.3ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 32.6ms
# Speed: 1.2ms preprocess, 32.6ms inference, 8.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 40.7ms
# Speed: 0.0ms preprocess, 40.7ms inference, 8.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 35.7ms
# Speed: 6.6ms preprocess, 35.7ms inference, 5.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 148.0ms
# Speed: 8.4ms preprocess, 148.0ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 139.8ms
# Speed: 5.9ms preprocess, 139.8ms inference, 10.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 41.6ms
# Speed: 7.9ms preprocess, 41.6ms inference, 10.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 40.6ms
# Speed: 0.0ms preprocess, 40.6ms inference, 9.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 48.2ms
# Speed: 0.0ms preprocess, 48.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 156.2ms
# Speed: 7.5ms preprocess, 156.2ms inference, 4.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 40.7ms
# Speed: 8.6ms preprocess, 40.7ms inference, 6.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 37.7ms
# Speed: 0.0ms preprocess, 37.7ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 37.8ms
# Speed: 0.0ms preprocess, 37.8ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 149.8ms
# Speed: 9.6ms preprocess, 149.8ms inference, 5.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 37.2ms
# Speed: 4.0ms preprocess, 37.2ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 41.5ms
# Speed: 2.0ms preprocess, 41.5ms inference, 5.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 40.1ms
# Speed: 0.0ms preprocess, 40.1ms inference, 6.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 153.5ms
# Speed: 3.0ms preprocess, 153.5ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 39.5ms
# Speed: 8.8ms preprocess, 39.5ms inference, 11.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Rotten Potatos, 40.9ms
# Speed: 9.6ms preprocess, 40.9ms inference, 8.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Rotten Potatos, 48.8ms
# Speed: 0.0ms preprocess, 48.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 154.8ms
# Speed: 8.1ms preprocess, 154.8ms inference, 4.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 32.9ms
# Speed: 2.5ms preprocess, 32.9ms inference, 5.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Rotten Potatos, 37.7ms
# Speed: 0.0ms preprocess, 37.7ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 29.0ms
# Speed: 11.1ms preprocess, 29.0ms inference, 9.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 135.0ms
# Speed: 2.6ms preprocess, 135.0ms inference, 5.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 49.3ms
# Speed: 0.0ms preprocess, 49.3ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Rotten Potatos, 44.8ms
# Speed: 0.6ms preprocess, 44.8ms inference, 8.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 48.3ms
# Speed: 0.0ms preprocess, 48.3ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 138.8ms
# Speed: 4.9ms preprocess, 138.8ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 48.4ms
# Speed: 0.0ms preprocess, 48.4ms inference, 5.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 48.8ms
# Speed: 2.1ms preprocess, 48.8ms inference, 5.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 49.6ms
# Speed: 7.2ms preprocess, 49.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 149.7ms
# Speed: 5.2ms preprocess, 149.7ms inference, 9.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 147.2ms
# Speed: 3.9ms preprocess, 147.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 30.2ms
# Speed: 9.1ms preprocess, 30.2ms inference, 9.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 40.5ms
# Speed: 0.0ms preprocess, 40.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 35.6ms
# Speed: 0.0ms preprocess, 35.6ms inference, 5.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 129.6ms
# Speed: 3.5ms preprocess, 129.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 40.4ms
# Speed: 8.4ms preprocess, 40.4ms inference, 9.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 47.7ms
# Speed: 3.0ms preprocess, 47.7ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 44.6ms
# Speed: 9.3ms preprocess, 44.6ms inference, 5.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 160.8ms
# Speed: 8.2ms preprocess, 160.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 148.8ms
# Speed: 2.0ms preprocess, 148.8ms inference, 5.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 40.1ms
# Speed: 0.0ms preprocess, 40.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 33.0ms
# Speed: 7.5ms preprocess, 33.0ms inference, 7.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 35.2ms
# Speed: 0.0ms preprocess, 35.2ms inference, 9.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 64.6ms
# Speed: 1.1ms preprocess, 64.6ms inference, 8.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 68.9ms
# Speed: 8.5ms preprocess, 68.9ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 79.8ms
# Speed: 6.0ms preprocess, 79.8ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 158.3ms
# Speed: 10.7ms preprocess, 158.3ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Rotten Potatos, 150.9ms
# Speed: 8.3ms preprocess, 150.9ms inference, 7.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 44.9ms
# Speed: 3.5ms preprocess, 44.9ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 49.1ms
# Speed: 0.0ms preprocess, 49.1ms inference, 7.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 50.8ms
# Speed: 0.0ms preprocess, 50.8ms inference, 9.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 71.9ms
# Speed: 5.0ms preprocess, 71.9ms inference, 5.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 161.9ms
# Speed: 6.1ms preprocess, 161.9ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 152.8ms
# Speed: 10.6ms preprocess, 152.8ms inference, 6.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 48.5ms
# Speed: 4.5ms preprocess, 48.5ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 49.7ms
# Speed: 2.5ms preprocess, 49.7ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 48.9ms
# Speed: 9.3ms preprocess, 48.9ms inference, 6.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 69.0ms
# Speed: 8.1ms preprocess, 69.0ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 79.9ms
# Speed: 5.4ms preprocess, 79.9ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 163.5ms
# Speed: 3.0ms preprocess, 163.5ms inference, 7.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 48.9ms
# Speed: 2.1ms preprocess, 48.9ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 41.0ms
# Speed: 8.0ms preprocess, 41.0ms inference, 11.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 48.1ms
# Speed: 5.5ms preprocess, 48.1ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 167.2ms
# Speed: 4.5ms preprocess, 167.2ms inference, 5.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 139.6ms
# Speed: 4.2ms preprocess, 139.6ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 38.7ms
# Speed: 4.6ms preprocess, 38.7ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Rotten Potatos, 40.5ms
# Speed: 0.0ms preprocess, 40.5ms inference, 6.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Rotten Potatos, 49.1ms
# Speed: 0.0ms preprocess, 49.1ms inference, 6.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Rotten Potatos, 153.2ms
# Speed: 2.8ms preprocess, 153.2ms inference, 4.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Rotten Potatos, 39.8ms
# Speed: 0.0ms preprocess, 39.8ms inference, 10.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Rotten Potatos, 40.8ms
# Speed: 0.0ms preprocess, 40.8ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 40.9ms
# Speed: 7.6ms preprocess, 40.9ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Rotten Potatos, 140.0ms
# Speed: 1.0ms preprocess, 140.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Rotten Potatos, 50.0ms
# Speed: 9.2ms preprocess, 50.0ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Rotten Potatos, 48.8ms
# Speed: 4.6ms preprocess, 48.8ms inference, 4.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Rotten Potatos, 43.7ms
# Speed: 0.0ms preprocess, 43.7ms inference, 7.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Rotten Potatos, 154.9ms
# Speed: 7.6ms preprocess, 154.9ms inference, 7.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Rotten Potatos, 31.0ms
# Speed: 4.1ms preprocess, 31.0ms inference, 9.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Rotten Potatos, 32.3ms
# Speed: 0.0ms preprocess, 32.3ms inference, 7.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 35.7ms
# Speed: 5.3ms preprocess, 35.7ms inference, 4.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 150.8ms
# Speed: 3.5ms preprocess, 150.8ms inference, 6.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 150.1ms
# Speed: 0.0ms preprocess, 150.1ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 33.6ms
# Speed: 6.7ms preprocess, 33.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 40.8ms
# Speed: 0.0ms preprocess, 40.8ms inference, 9.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 40.3ms
# Speed: 5.2ms preprocess, 40.3ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 148.0ms
# Speed: 0.0ms preprocess, 148.0ms inference, 10.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 39.9ms
# Speed: 0.0ms preprocess, 39.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Rotten Potatos, 34.6ms
# Speed: 4.6ms preprocess, 34.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Rotten Potatos, 37.0ms
# Speed: 2.6ms preprocess, 37.0ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Rotten Potatos, 149.6ms
# Speed: 0.0ms preprocess, 149.6ms inference, 9.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Rotten Potatos, 149.7ms
# Speed: 0.0ms preprocess, 149.7ms inference, 5.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 30.7ms
# Speed: 9.1ms preprocess, 30.7ms inference, 9.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 32.8ms
# Speed: 0.0ms preprocess, 32.8ms inference, 8.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 32.0ms
# Speed: 8.4ms preprocess, 32.0ms inference, 5.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 146.7ms
# Speed: 4.5ms preprocess, 146.7ms inference, 8.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 39.7ms
# Speed: 1.8ms preprocess, 39.7ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Rotten Potatos, 36.0ms
# Speed: 4.2ms preprocess, 36.0ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 37.9ms
# Speed: 4.7ms preprocess, 37.9ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 68.8ms
# Speed: 0.0ms preprocess, 68.8ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 75.8ms
# Speed: 8.5ms preprocess, 75.8ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 85.8ms
# Speed: 5.1ms preprocess, 85.8ms inference, 10.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 179.1ms
# Speed: 8.2ms preprocess, 179.1ms inference, 5.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Rotten Potatos, 128.7ms
# Speed: 8.1ms preprocess, 128.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 Rotten Potatos, 48.6ms
# Speed: 0.0ms preprocess, 48.6ms inference, 10.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Rotten Potatos, 49.8ms
# Speed: 7.6ms preprocess, 49.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 Rotten Potatos, 50.1ms
# Speed: 8.8ms preprocess, 50.1ms inference, 7.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 Rotten Potatos, 150.0ms
# Speed: 4.2ms preprocess, 150.0ms inference, 10.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 143.1ms
# Speed: 10.9ms preprocess, 143.1ms inference, 5.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 30.7ms
# Speed: 0.5ms preprocess, 30.7ms inference, 9.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 31.1ms
# Speed: 5.5ms preprocess, 31.1ms inference, 9.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 Rotten Potatos, 35.9ms
# Speed: 4.6ms preprocess, 35.9ms inference, 5.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 142.8ms
# Speed: 9.3ms preprocess, 142.8ms inference, 8.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 48.6ms
# Speed: 0.0ms preprocess, 48.6ms inference, 9.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Rotten Potatos, 39.2ms
# Speed: 10.1ms preprocess, 39.2ms inference, 10.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Rotten Potatos, 49.4ms
# Speed: 0.0ms preprocess, 49.4ms inference, 10.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Rotten Potatos, 156.8ms
# Speed: 1.5ms preprocess, 156.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Rotten Potatos, 149.5ms
# Speed: 10.6ms preprocess, 149.5ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Rotten Potatos, 41.3ms
# Speed: 0.0ms preprocess, 41.3ms inference, 6.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Rotten Potatos, 40.6ms
# Speed: 8.2ms preprocess, 40.6ms inference, 7.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Rotten Potatos, 42.1ms
# Speed: 0.0ms preprocess, 42.1ms inference, 8.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Rotten Potatos, 137.2ms
# Speed: 5.0ms preprocess, 137.2ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Rotten Potatos, 50.6ms
# Speed: 4.5ms preprocess, 50.6ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Rotten Potatos, 49.3ms
# Speed: 0.0ms preprocess, 49.3ms inference, 7.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 47.9ms
# Speed: 5.5ms preprocess, 47.9ms inference, 8.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 Rotten Potatos, 159.2ms
# Speed: 9.2ms preprocess, 159.2ms inference, 8.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 Rotten Potatos, 152.0ms
# Speed: 2.9ms preprocess, 152.0ms inference, 7.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 30.8ms
# Speed: 5.5ms preprocess, 30.8ms inference, 9.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 30.6ms
# Speed: 10.1ms preprocess, 30.6ms inference, 9.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 32.8ms
# Speed: 6.0ms preprocess, 32.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 57.9ms
# Speed: 3.5ms preprocess, 57.9ms inference, 8.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 67.3ms
# Speed: 3.7ms preprocess, 67.3ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 155.0ms
# Speed: 7.8ms preprocess, 155.0ms inference, 5.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 48.2ms
# Speed: 5.0ms preprocess, 48.2ms inference, 5.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 49.3ms
# Speed: 0.0ms preprocess, 49.3ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 49.5ms
# Speed: 4.8ms preprocess, 49.5ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 154.9ms
# Speed: 5.9ms preprocess, 154.9ms inference, 8.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 146.7ms
# Speed: 4.0ms preprocess, 146.7ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 40.8ms
# Speed: 1.0ms preprocess, 40.8ms inference, 9.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 39.8ms
# Speed: 6.0ms preprocess, 39.8ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 42.7ms
# Speed: 4.0ms preprocess, 42.7ms inference, 6.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 157.4ms
# Speed: 0.0ms preprocess, 157.4ms inference, 5.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 147.4ms
# Speed: 7.1ms preprocess, 147.4ms inference, 7.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Rotten Potatos, 35.0ms
# Speed: 4.6ms preprocess, 35.0ms inference, 6.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 37.7ms
# Speed: 1.5ms preprocess, 37.7ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 35.0ms
# Speed: 5.1ms preprocess, 35.0ms inference, 5.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 149.2ms
# Speed: 0.0ms preprocess, 149.2ms inference, 4.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 148.8ms
# Speed: 0.0ms preprocess, 148.8ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 142.9ms
# Speed: 4.1ms preprocess, 142.9ms inference, 7.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 40.6ms
# Speed: 6.0ms preprocess, 40.6ms inference, 8.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 38.9ms
# Speed: 5.3ms preprocess, 38.9ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 40.0ms
# Speed: 2.0ms preprocess, 40.0ms inference, 7.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Rotten Potatos, 153.8ms
# Speed: 4.6ms preprocess, 153.8ms inference, 6.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 130.1ms
# Speed: 9.1ms preprocess, 130.1ms inference, 9.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Rotten Potatos, 40.0ms
# Speed: 2.3ms preprocess, 40.0ms inference, 9.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 45.5ms
# Speed: 5.3ms preprocess, 45.5ms inference, 3.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 48.9ms
# Speed: 0.0ms preprocess, 48.9ms inference, 6.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 158.7ms
# Speed: 8.0ms preprocess, 158.7ms inference, 8.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 155.1ms
# Speed: 1.2ms preprocess, 155.1ms inference, 7.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 30.8ms
# Speed: 10.4ms preprocess, 30.8ms inference, 9.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 44.1ms
# Speed: 0.0ms preprocess, 44.1ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Rotten Potatos, 40.0ms
# Speed: 0.0ms preprocess, 40.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 148.5ms
# Speed: 3.3ms preprocess, 148.5ms inference, 8.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Rotten Potatos, 38.9ms
# Speed: 9.2ms preprocess, 38.9ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 31.2ms
# Speed: 9.2ms preprocess, 31.2ms inference, 8.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 40.9ms
# Speed: 0.0ms preprocess, 40.9ms inference, 8.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 65.5ms
# Speed: 0.0ms preprocess, 65.5ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 76.6ms
# Speed: 2.5ms preprocess, 76.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 90.0ms
# Speed: 0.0ms preprocess, 90.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 161.9ms
# Speed: 8.6ms preprocess, 161.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 45.6ms
# Speed: 5.5ms preprocess, 45.6ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 49.2ms
# Speed: 3.0ms preprocess, 49.2ms inference, 7.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 48.5ms
# Speed: 7.5ms preprocess, 48.5ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 155.5ms
# Speed: 4.0ms preprocess, 155.5ms inference, 8.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 39.2ms
# Speed: 0.0ms preprocess, 39.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 31.3ms
# Speed: 9.3ms preprocess, 31.3ms inference, 7.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 36.4ms
# Speed: 2.5ms preprocess, 36.4ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 53.5ms
# Speed: 6.1ms preprocess, 53.5ms inference, 8.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 68.2ms
# Speed: 0.0ms preprocess, 68.2ms inference, 5.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 163.3ms
# Speed: 0.0ms preprocess, 163.3ms inference, 5.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 136.8ms
# Speed: 1.0ms preprocess, 136.8ms inference, 3.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Rotten Potatos, 38.8ms
# Speed: 1.9ms preprocess, 38.8ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Rotten Potatos, 40.8ms
# Speed: 2.1ms preprocess, 40.8ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 Rotten Potatos, 41.0ms
# Speed: 0.0ms preprocess, 41.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 Rotten Potatos, 151.0ms
# Speed: 2.7ms preprocess, 151.0ms inference, 9.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 Rotten Potatos, 45.7ms
# Speed: 0.0ms preprocess, 45.7ms inference, 3.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Rotten Potatos, 43.5ms
# Speed: 4.6ms preprocess, 43.5ms inference, 6.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 41.5ms
# Speed: 0.0ms preprocess, 41.5ms inference, 7.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 90.7ms
# Speed: 8.0ms preprocess, 90.7ms inference, 9.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 152.3ms
# Speed: 8.6ms preprocess, 152.3ms inference, 9.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 150.0ms
# Speed: 7.8ms preprocess, 150.0ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 33.3ms
# Speed: 7.0ms preprocess, 33.3ms inference, 7.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 30.9ms
# Speed: 9.0ms preprocess, 30.9ms inference, 10.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 34.2ms
# Speed: 3.6ms preprocess, 34.2ms inference, 5.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 54.4ms
# Speed: 5.1ms preprocess, 54.4ms inference, 6.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Rotten Potatos, 70.1ms
# Speed: 0.0ms preprocess, 70.1ms inference, 3.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Rotten Potatos, 73.5ms
# Speed: 8.9ms preprocess, 73.5ms inference, 7.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Rotten Potatos, 158.2ms
# Speed: 8.2ms preprocess, 158.2ms inference, 6.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 34.0ms
# Speed: 5.4ms preprocess, 34.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 37.3ms
# Speed: 3.0ms preprocess, 37.3ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 39.5ms
# Speed: 0.0ms preprocess, 39.5ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 89.0ms
# Speed: 0.0ms preprocess, 89.0ms inference, 8.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 153.5ms
# Speed: 8.3ms preprocess, 153.5ms inference, 6.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 41.9ms
# Speed: 0.0ms preprocess, 41.9ms inference, 9.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 30.8ms
# Speed: 5.5ms preprocess, 30.8ms inference, 5.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 39.0ms
# Speed: 0.0ms preprocess, 39.0ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Rotten Potatos, 53.2ms
# Speed: 4.0ms preprocess, 53.2ms inference, 8.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 70.8ms
# Speed: 0.0ms preprocess, 70.8ms inference, 3.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 70.8ms
# Speed: 5.0ms preprocess, 70.8ms inference, 5.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 168.2ms
# Speed: 4.7ms preprocess, 168.2ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 159.9ms
# Speed: 4.0ms preprocess, 159.9ms inference, 6.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 34.1ms
# Speed: 6.0ms preprocess, 34.1ms inference, 6.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 31.1ms
# Speed: 1.5ms preprocess, 31.1ms inference, 9.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 39.3ms
# Speed: 0.0ms preprocess, 39.3ms inference, 2.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 54.4ms
# Speed: 3.0ms preprocess, 54.4ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 68.8ms
# Speed: 0.0ms preprocess, 68.8ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 160.8ms
# Speed: 0.0ms preprocess, 160.8ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 152.9ms
# Speed: 8.6ms preprocess, 152.9ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 156.7ms
# Speed: 4.1ms preprocess, 156.7ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 146.5ms
# Speed: 8.1ms preprocess, 146.5ms inference, 8.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 122.6ms
# Speed: 8.2ms preprocess, 122.6ms inference, 8.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 41.0ms
# Speed: 7.5ms preprocess, 41.0ms inference, 9.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 40.1ms
# Speed: 9.0ms preprocess, 40.1ms inference, 8.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 43.1ms
# Speed: 11.0ms preprocess, 43.1ms inference, 7.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 154.9ms
# Speed: 5.6ms preprocess, 154.9ms inference, 9.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Rotten Potatos, 155.1ms
# Speed: 4.0ms preprocess, 155.1ms inference, 12.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 50.1ms
# Speed: 2.5ms preprocess, 50.1ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 48.9ms
# Speed: 0.0ms preprocess, 48.9ms inference, 7.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 43.4ms
# Speed: 5.5ms preprocess, 43.4ms inference, 7.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 155.5ms
# Speed: 5.1ms preprocess, 155.5ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 41.0ms
# Speed: 3.8ms preprocess, 41.0ms inference, 8.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Fresh Potato, 36.5ms
# Speed: 4.2ms preprocess, 36.5ms inference, 4.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 32.2ms
# Speed: 3.5ms preprocess, 32.2ms inference, 4.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 122.6ms
# Speed: 2.8ms preprocess, 122.6ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 44.4ms
# Speed: 4.5ms preprocess, 44.4ms inference, 0.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 (no detections), 40.4ms
# Speed: 3.5ms preprocess, 40.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 40.9ms
# Speed: 2.5ms preprocess, 40.9ms inference, 7.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 46.6ms
# Speed: 2.0ms preprocess, 46.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 74.0ms
# Speed: 1.0ms preprocess, 74.0ms inference, 5.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 Rotten Potato, 79.1ms
# Speed: 2.6ms preprocess, 79.1ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 main(video_path, model, resize_factor, roi_coordinates)
#
# Cell In[11], line 27, in main(video_path, model, resize_factor, roi_coordinates)
#      24     break
#      26 # Call the area_calculated function
# ---> 27 processed_frame = area_calculated(frame, width, height, resize_factor, X1, Y1, X2, Y2)
#      28 predicted_frame = model_predict(frame, model, width, height, resize_factor, X1, Y1, X2, Y2)
#      30 collage = np.hstack((predicted_frame, processed_frame))
#
# Cell In[9], line 20, in area_calculated(frame, width, height, resize_factor, X1, Y1, X2, Y2)
#      17     return resized_frame  # Skip this frame if ROI is invalid
#      19 # Apply K-means clustering and morphological operations inside the ROI
# ---> 20 mask = kmeans_segmentation(roi_frame, k=2)
#      22 # Convert the mask back to 3 channels to overlay it on the original frame
#      23 mask_3channel = cv2.cvtColor(mask, cv2.COLOR_GRAY2BGR)
#
# Cell In[8], line 11, in kmeans_segmentation(roi_frame, k)
#       8 criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 100, 0.2)
#      10 # Apply K-means clustering
# ---> 11 _, labels, centers = cv2.kmeans(pixel_values, k, None, criteria, 10, cv2.KMEANS_RANDOM_CENTERS)
#      13 # Convert back to 8-bit values and reshape to the original image dimensions
#      14 centers = np.uint8(centers)
#
# KeyboardInterrupt:
